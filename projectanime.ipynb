# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryan123Yad/numpy-practice/blob/main/projectanime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
